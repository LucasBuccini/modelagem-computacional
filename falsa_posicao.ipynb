# %%
from matplotlib.pyplot import * 
from numpy import *
fx = lambda x: x**10 - 1

x = linspace(0,1.4,100)
plot(x,fx(x),"b-",label="Função")
xl = float(input("Qual o x inicial: "))
xu = float(input("Qual o x final: "))
erro = float(input("Qual a tolerancia do erro: "))
xr = xu - ((fx(xu)*(xl-xu))/(fx(xl)-fx(xu)))
print(f"xl = {xl}, xu = {xu}, xr = {xr}, erro = {fx(xr)}")
cont=0
if(fx(xl)*fx(xu)<0):
    while(abs(fx(xr))>erro):
        if (fx(xl)*fx(xr)<0):
            xu = xr
        elif (fx(xr)*fx(xu)<0):
            xl=xr
        
        print(f"xl = {xl}, xu = {xu}, xr = {xr}, erro = {fx(xr)}")
        xr = xu - ((fx(xu)*(xl-xu))/(fx(xl)-fx(xu)))
        cont+=1
    print(f"Raiz encontrada em x = {xr}, com {cont} interações")
    plot(xr,0,"ro",label="Raiz")
    grid()
    legend()
else:
    print("Valores invalidos, intervalo fora da raiz")
# Out:
# xl = 0.0, xu = 1.4, xr = 0.048400258247050854, erro = -0.9999999999999295
# xl = 0.048400258247050854, xu = 1.4, xr = 0.048400258247050854, erro = -0.9999999999999295
# xl = 0.09512724149525487, xu = 1.4, xr = 0.09512724149525487, erro = -0.9999999999393195
# xl = 0.14023879755773438, xu = 1.4, xr = 0.14023879755773438, erro = -0.9999999970577349
# xl = 0.18379077423960943, xu = 1.4, xr = 0.18379077423960943, erro = -0.9999999560218382
# xl = 0.22583708717530881, xu = 1.4, xr = 0.22583708717530881, erro = -0.9999996548938992
# xl = 0.26642977951141367, xu = 1.4, xr = 0.26642977951141367, erro = -0.9999981976976302
# xl = 0.30561906233133174, xu = 1.4, xr = 0.30561906233133174, erro = -0.9999928910675205
# xl = 0.34345331695518344, xu = 1.4, xr = 0.34345331695518344, erro = -0.9999771609965556
# xl = 0.37997903464398397, xu = 1.4, xr = 0.37997903464398397, erro = -0.9999372525110655
# xl = 0.41524066852383956, xu = 1.4, xr = 0.41524066852383956, erro = -0.9998475951402179
# xl = 0.4492803778335185, xu = 1.4, xr = 0.4492803778335185, erro = -0.999664899933943
# xl = 0.48213765532531916, xu = 1.4, xr = 0.48213765532531916, erro = -0.9993212489484274
# xl = 0.5138488431269885, xu = 1.4, xr = 0.5138488431269885, erro = -0.9987166242436016
# xl = 0.5444465585000159, xu = 1.4, xr = 0.5444465585000159, erro = -0.997711491291804
# xl = 0.5739590667672305, xu = 1.4, xr = 0.5739590667672305, erro = -0.9961202011697943
# xl = 0.60240965274673, xu = 1.4, xr = 0.60240965274673, erro = -0.9937061089340288
# xl = 0.6298160532922185, xu = 1.4, xr = 0.6298160532922185, erro = -0.9901794172118968
# xl = 0.6561900212166352, xu = 1.4, xr = 0.6561900212166352, erro = -0.9851988241929449
# xl = 0.6815370941293791, xu = 1.4, xr = 0.6815370941293791, erro = -0.9783780438476084
# xl = 0.7058566394318846, xu = 1.4, xr = 0.7058566394318846, erro = -0.9692981149511726
# xl = 0.7291422374705647, xu = 1.4, xr = 0.7291422374705647, erro = -0.9575260583511744
# xl = 0.751382447174076, xu = 1.4, xr = 0.751382447174076, erro = -0.9426398267773031
# xl = 0.7725619714542595, xu = 1.4, xr = 0.7725619714542595, erro = -0.9242586107867007
# xl = 0.7926632035644775, xu = 1.4, xr = 0.7926632035644775, erro = -0.9020764878535733
# xl = 0.8116680928661478, xu = 1.4, xr = 0.8116680928661478, erro = -0.8758962972144176
# xl = 0.8295602238932446, xu = 1.4, xr = 0.8295602238932446, erro = -0.8456597492710063
# xl = 0.8463269632507576, xu = 1.4, xr = 0.8463269632507576, erro = -0.8114694330901314
# xl = 0.8619615027843518, xu = 1.4, xr = 0.8619615027843518, erro = -0.7735988145515884
# xl = 0.8764646217397982, xu = 1.4, xr = 0.8764646217397982, erro = -0.732487607171783
# xl = 0.8898460092760817, xu = 1.4, xr = 0.8898460092760817, erro = -0.6887218971864404
# xl = 0.9021250308502756, xu = 1.4, xr = 0.9021250308502756, erro = -0.643000727108693
# xl = 0.9133308815478398, xu = 1.4, xr = 0.9133308815478398, erro = -0.5960929602327838
# xl = 0.9235021362463136, xu = 1.4, xr = 0.9235021362463136, erro = -0.5487896595464317
# xl = 0.932685768934186, xu = 1.4, xr = 0.932685768934186, erro = -0.5018576068951754
# xl = 0.9409357614082808, xu = 1.4, xr = 0.9409357614082808, erro = -0.4559989382090017
# xl = 0.9483114486579998, xu = 1.4, xr = 0.9483114486579998, erro = -0.4118204281615958
# xl = 0.9548757531258545, xu = 1.4, xr = 0.9548757531258545, erro = -0.36981413798978335
# xl = 0.9606934457507779, xu = 1.4, xr = 0.9606934457507779, erro = -0.3303493761746108
# xl = 0.9658295441713669, xu = 1.4, xr = 0.9658295441713669, erro = -0.29367454019558936
# xl = 0.9703479245618114, xu = 1.4, xr = 0.9703479245618114, erro = -0.25992656914042955
# xl = 0.9743101894694015, xu = 1.4, xr = 0.9743101894694015, erro = -0.22914544173168594
# xl = 0.977774804195739, xu = 1.4, xr = 0.977774804195739, erro = -0.20129129184026107
# xl = 0.9807964911874953, xu = 1.4, xr = 0.9807964911874953, erro = -0.17626212543301079
# xl = 0.9834258562729254, xu = 1.4, xr = 0.9834258562729254, erro = -0.15391065497594192
# xl = 0.9857092118203811, xu = 1.4, xr = 0.9857092118203811, erro = -0.13405930036769165
# xl = 0.9876885587128189, xu = 1.4, xr = 0.9876885587128189, erro = -0.11651286526043514
# xl = 0.9894016898900277, xu = 1.4, xr = 0.9894016898900277, erro = -0.10106875059106113
# xl = 0.9908823816455663, xu = 1.4, xr = 0.9908823816455663, erro = -0.08752480941204
# xl = 0.9921606436654771, xu = 1.4, xr = 0.9921606436654771, erro = -0.0756850923807032
# xl = 0.9932630040581857, xu = 1.4, xr = 0.9932630040581857, erro = -0.06536380289014321
# xl = 0.9942128107447066, xu = 1.4, xr = 0.9942128107447066, erro = -0.05638779708987862
# xl = 0.9950305351980666, xu = 1.4, xr = 0.9950305351980666, erro = -0.04859794644619353
# xl = 0.9957340684692395, xu = 1.4, xr = 0.9957340684692395, erro = -0.04184964424240034
# xl = 0.9963390026693255, xu = 1.4, xr = 0.9963390026693255, erro = -0.036012693340927604
# xl = 0.9968588936282832, xu = 1.4, xr = 0.9968588936282832, erro = -0.03097076766072926
# xl = 0.9973055023956332, xu = 1.4, xr = 0.9973055023956332, erro = -0.026620598278440655
# xl = 0.9976890146820827, xu = 1.4, xr = 0.9976890146820827, erro = -0.022870998875246573
# xl = 0.9980182383585567, xu = 1.4, xr = 0.9980182383585567, erro = -0.019641815094395776
# xl = 0.9983007798190396, xu = 1.4, xr = 0.9983007798190396, erro = -0.016862858096439615
# xl = 0.998543200452751, xu = 1.4, xr = 0.998543200452751, erro = -0.014472863612609688
# xl = 0.998751154723483, xu = 1.4, xr = 0.998751154723483, erro = -0.01241850332758887
# xl = 0.9989295114709049, xu = 1.4, xr = 0.9989295114709049, erro = -0.010653464666048995
# xl = 0.9990824600706696, xu = 1.4, xr = 0.9990824600706696, erro = -0.009137607261111125
# xl = 0.9992136030480805, xu = 1.4, xr = 0.9992136030480805, erro = -0.007836198890336266
# xl = 0.99932603665701, xu = 1.4, xr = 0.99932603665701, erro = -0.0067192299260092625
# xl = 0.9994224208285787, xu = 1.4, xr = 0.9994224208285787, erro = -0.005760802915882213
# xl = 0.9995050397748899, xu = 1.4, xr = 0.9995050397748899, erro = -0.004938592436381506
# xl = 0.9995758544102601, xu = 1.4, xr = 0.9995758544102601, erro = -0.004233369570376455
# xl = 0.9996365476315241, xu = 1.4, xr = 0.9996365476315241, erro = -0.003628585049352706
# xl = 0.9996885633837456, xu = 1.4, xr = 0.9996885633837456, erro = -0.0031100051109538285
# xl = 0.9997331403301684, xu = 1.4, xr = 0.9997331403301684, erro = -0.002665394343999594
# xl = 0.9997713408466291, xu = 1.4, xr = 0.9997713408466291, erro = -0.002284240142409577
# xl = 0.9998040759712978, xu = 1.4, xr = 0.9998040759712978, erro = -0.00195751380908038
# xl = 0.9998321268604653, xu = 1.4, xr = 0.9998321268604653, erro = -0.001677463800294099
# xl = 0.999856163229748, xu = 1.4, xr = 0.999856163229748, erro = -0.0014374370537894032
# xl = 0.999876759196983, xu = 1.4, xr = 0.999876759196983, erro = -0.001231724781440513
# xl = 0.9998944068875568, xu = 1.4, xr = 0.9998944068875568, erro = -0.0010554295199453056
# Raiz encontrada em x = 0.9999095281142634, com 77 interações

# %%
f = lambda x: -4 + 1.8*x**2 + 1.2*x**3 - 0.3*x**4
ff = lambda x: 3.6*x + 3.6*x**2 - 1.2*x**3
fff = lambda x: 3.6 + 7.2*x - 3.6*x**2

x = linspace(0,5,100)
plot(x,f(x),label="Função")
grid()
xl = float(input("Qual o x inicial: "))
xu = float(input("Qual o x final: "))
erro = float(input("Qual a tolerancia do erro: "))
xr = xu - ((ff(xu)*(xl-xu))/(ff(xl)-ff(xu)))
print(f"xl = {xl}, xu = {xu}, xr = {xr}, erro = {ff(xr)}")

if(ff(xl)*ff(xu)<=0):
    while(abs(ff(xr))>erro):
        if (ff(xl)*ff(xr)<0):
            xu = xr
        elif (ff(xr)*ff(xu)<0):
            xl=xr
        
        print(f"xl = {xl}, xu = {xu}, xr = {xr}, erro = {fx(xr)}")
        xr = xu - ((ff(xu)*(xl-xu))/(ff(xl)-ff(xu)))
        cont+=1
    if(fff(xr)<0):
        print(f"Maximo encontrad0 em x = {xr}, com {cont} interações")
        plot(xr,f(xr),"ro",label="Raiz")
        legend()
    else:
        print(f"Intervalo possui um minimo em {xr}, nao foi possivel encontrar o maximo, digite um intervalo que não passe por esse ponto")
else:
    print("Valores invalidos, intervalo fora da raiz")
# Out:
# xl = 1.0, xu = 4.0, xr = 2.666666666666667, erro = 12.44444444444444
# xl = 2.666666666666667, xu = 4.0, xr = 2.666666666666667, erro = 18182.91207302412
# xl = 3.6288659793814433, xu = 4.0, xr = 3.6288659793814433, erro = 396011.8625702595
# xl = 3.7752497656114707, xu = 4.0, xr = 3.7752497656114707, erro = 588106.7367615657
# xl = 3.7897808316574397, xu = 4.0, xr = 3.7897808316574397, erro = 611139.3356128915
# Maximo encontrad0 em x = 3.7911469225523304, com 100 interações

# %%
from scipy.optimize import *


x = linspace(0,5,100)
plot(x,f(x),label="Função")
grid()
xl = float(input("Qual o x inicial: "))
xu = float(input("Qual o x final: "))

maximo = bisect(ff,xl,xu)

if(fff(maximo)<0):
    print(f"Maximo encontrado em {xr}")
    plot(xr,f(xr),"ro",label="Raiz")
    legend()
else:
    print(f"Ponto encontrado em {xr} é um minimo, digite um intervalo superior")
# Out:
# Maximo encontrado em 3.7911469225523304
